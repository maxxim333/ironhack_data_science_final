# %% [markdown]
# # Information:
# ## Data Download:
#
# wget -r -N -c -np https://physionet.org/files/tappy/1.0.0/
#
# ## Data explanation:
#
# https://physionet.org/content/tappy/1.0.0/
#
# ## Original Article:
#
# https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0188226#pone-0188226-t003

# %% [markdown]
# # Importing stuff

# %%
import os
import pandas as pd
import glob
import time
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
import time
from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType, StringType, IntegerType, FloatType

# %%
# !pwd
# Out:
# /home/biomedmax/final_project_ironhack

# %%
# !pwd
# Out:
# /home/biomedmax/final_project_ironhack

# %%
# Same but in form of function

def read_data(filepath):
    data = pd.read_csv(filepath, delimiter="\t", header = None)
    data.columns = ['UserKey', 'Date', 'Timestamp', 'Hand', 'HoldTime', 'Direction', 'LatencyTime', 'FlightTime', "Remove"]

    data.drop("Remove", axis =1, inplace = True)
    return data

# %%
#data = read_data("physionetdotorg/files/tappy/1/extracted/TappyData/ZWBPPNQCUX_1608.txt")
data = read_data("physionetdotorg/files/maksymdata/MAKSYM0000_1708.txt")

# %%
data
# Out:
#         UserKey    Date     Timestamp Hand  HoldTime Direction  LatencyTime  \
# 0    MAKSYM0000  170824  10:10:10.111    R     77.96        LR       169.87
# 1    MAKSYM0000  170824  10:10:10.111    R     76.26        RR       375.79
# 2    MAKSYM0000  170824  10:10:10.111    S    101.36        LS        88.34
# 3    MAKSYM0000  170824  10:10:10.111    S     93.00        LS        88.34
# 4    MAKSYM0000  170824  10:10:10.111    L     63.72        SL       185.22
# ..          ...     ...           ...  ...       ...       ...          ...
# 171  MAKSYM0000  170824  10:10:10.111    L     73.77        SL       246.07
# 172  MAKSYM0000  170824  10:10:10.111    L     84.69        LL        67.18
# 173  MAKSYM0000  170824  10:10:10.111    L    123.19        LL        67.18
# 174  MAKSYM0000  170824  10:10:10.111    L     99.03        LL       147.24
# 175  MAKSYM0000  170824  10:10:10.111    R     88.20        LR       143.19
#
#      FlightTime
# 0         96.40
# 1        297.83
# 2        132.53
# 3        132.53
# 4         92.22
# ..          ...
# 171      150.86
# 172      153.42
# 173      153.42
# 174       24.05
# 175       44.16
#
# [176 rows x 8 columns]

# %%
# Function to remove leading zeros from a float represented as a string
def remove_leading_zeros_from_float(value):
    # Check if the value is a string and if it contains a leading zero
    if isinstance(value, str) and value.lstrip('0').replace('.', '').isdigit():
        return float(value.lstrip('0'))
    return value

# Apply changes to the columns that need it
def apply_remove_leading_zeros_from_float(data):
    if 'HoldTime' in data.columns:
        data['HoldTime'] = data['HoldTime'].apply(remove_leading_zeros_from_float)
    
    if 'LatencyTime' in data.columns:
        data['LatencyTime'] = data['LatencyTime'].apply(remove_leading_zeros_from_float)
    
    if 'FlightTime' in data.columns:
        data['FlightTime'] = data['FlightTime'].apply(remove_leading_zeros_from_float)

apply_remove_leading_zeros_from_float(data)

# %%
print(data.head())
# Out:
#       UserKey    Date     Timestamp Hand  HoldTime Direction  LatencyTime  \
# 0  MAKSYM0000  170824  10:10:10.111    R     77.96        LR       169.87
# 1  MAKSYM0000  170824  10:10:10.111    R     76.26        RR       375.79
# 2  MAKSYM0000  170824  10:10:10.111    S    101.36        LS        88.34
# 3  MAKSYM0000  170824  10:10:10.111    S     93.00        LS        88.34
# 4  MAKSYM0000  170824  10:10:10.111    L     63.72        SL       185.22
#
#    FlightTime
# 0       96.40
# 1      297.83
# 2      132.53
# 3      132.53
# 4       92.22

# %%
data.dtypes
# Out:
# UserKey         object
# Date             int64
# Timestamp       object
# Hand            object
# HoldTime       float64
# Direction       object
# LatencyTime    float64
# FlightTime     float64
# dtype: object

# %%
len(data)
# Out:
# 176

# %% [markdown]
# ### Add quality control to each row. Delete those that dont qualify

# %%
# Function to validate each row
def validate_row(row):
    if not (isinstance(row['UserKey'], str) and len(row['UserKey']) == 10 and row['UserKey'].isalnum()):
        return False

    
    
    if not (isinstance(row['Date'], int) and len(str(row['Date'])) == 6):
        return False



    try:
        pd.to_datetime(str(row['Date']), format='%d%m%y')
    except ValueError:
        return False
    if not (isinstance(row['Timestamp'], str) and pd.to_datetime(row['Timestamp'], format='%H:%M:%S.%f', errors='coerce') is not pd.NaT):
        return False
    if not (row['Hand'] in ['L', 'R', 'S']):
        return False
    if not (isinstance(row['HoldTime'], float) or isinstance(row['HoldTime'], int)):
        return False
    if not (isinstance(row['Direction'], str) and len(row['Direction']) == 2 and all(char in ['L', 'R', 'S'] for char in row['Direction'])):
        return False
    if not (isinstance(row['LatencyTime'], float) or isinstance(row['LatencyTime'], int)):
        return False
    if not (isinstance(row['FlightTime'], float) or isinstance(row['FlightTime'], int)):
        return False
        
    return True

# Apply the validation function to each row
data['Valid'] = data.apply(validate_row, axis=1)

# Filter out invalid rows
data = data[data['Valid'] == True]

# Drop the 'Valid' column as it's no longer needed
data = data.drop(columns=['Valid'])

# %%
len(data)
# Out:
# 176

# %%
print(data.head())
# Out:
#       UserKey    Date     Timestamp Hand  HoldTime Direction  LatencyTime  \
# 0  MAKSYM0000  170824  10:10:10.111    R     77.96        LR       169.87
# 1  MAKSYM0000  170824  10:10:10.111    R     76.26        RR       375.79
# 2  MAKSYM0000  170824  10:10:10.111    S    101.36        LS        88.34
# 3  MAKSYM0000  170824  10:10:10.111    S     93.00        LS        88.34
# 4  MAKSYM0000  170824  10:10:10.111    L     63.72        SL       185.22
#
#    FlightTime
# 0       96.40
# 1      297.83
# 2      132.53
# 3      132.53
# 4       92.22

# %%
len(data["Date"])
# Out:
# 176

# %% [markdown]
# ### The datatypes are weird. Going to change them

# %%
def variable_conversion_function(data):

    # Convert 'Timestamp' to datetime with format 'HH:MM:SS.SSS' and extract time
    data['Timestamp'] = pd.to_datetime(data['Timestamp'], format='%H:%M:%S.%f').dt.time
    
    # Convert 'UserKey', 'Hand', and 'Direction' to string
    data['UserKey'] = data['UserKey'].astype(str)
    data['Hand'] = data['Hand'].astype(str)
    data['Direction'] = data['Direction'].astype(str)
    
    # Convert the rest to float
    data['HoldTime'] = data['HoldTime'].astype(float)
    data['LatencyTime'] = data['LatencyTime'].astype(float)
    data['FlightTime'] = data['FlightTime'].astype(float)

    return data

variable_conversion_function(data)

# Verify the changes
print(data.dtypes)
print(data)
# Out:
# UserKey         object
# Date             int64
# Timestamp       object
# Hand            object
# HoldTime       float64
# Direction       object
# LatencyTime    float64
# FlightTime     float64
# dtype: object
#         UserKey    Date        Timestamp Hand  HoldTime Direction  \
# 0    MAKSYM0000  170824  10:10:10.111000    R     77.96        LR
# 1    MAKSYM0000  170824  10:10:10.111000    R     76.26        RR
# 2    MAKSYM0000  170824  10:10:10.111000    S    101.36        LS
# 3    MAKSYM0000  170824  10:10:10.111000    S     93.00        LS
# 4    MAKSYM0000  170824  10:10:10.111000    L     63.72        SL
# ..          ...     ...              ...  ...       ...       ...
# 171  MAKSYM0000  170824  10:10:10.111000    L     73.77        SL
# 172  MAKSYM0000  170824  10:10:10.111000    L     84.69        LL
# 173  MAKSYM0000  170824  10:10:10.111000    L    123.19        LL
# 174  MAKSYM0000  170824  10:10:10.111000    L     99.03        LL
# 175  MAKSYM0000  170824  10:10:10.111000    R     88.20        LR
#
#      LatencyTime  FlightTime
# 0         169.87       96.40
# 1         375.79      297.83
# 2          88.34      132.53
# 3          88.34      132.53
# 4         185.22       92.22
# ..           ...         ...
# 171       246.07      150.86
# 172        67.18      153.42
# 173        67.18      153.42
# 174       147.24       24.05
# 175       143.19       44.16
#
# [176 rows x 8 columns]

# %%
data["Date"]
# Out:
# 0      170824
# 1      170824
# 2      170824
# 3      170824
# 4      170824
#         ...
# 171    170824
# 172    170824
# 173    170824
# 174    170824
# 175    170824
# Name: Date, Length: 176, dtype: int64

# %% [markdown]
# ### Calculate the metrics

# %%
datagrouped = data.groupby(["UserKey", "Hand" , "Direction"]).mean(["HoldTime","LatencyTime","FlightTime"])

# %%
datagrouped
# Out:
#                                Date    HoldTime  LatencyTime  FlightTime
# UserKey    Hand Direction
# MAKSYM0000 L    LL         170824.0   93.411200   175.358000  189.420800
#                 RL         170824.0   84.521071   201.381429  124.586429
#                 SL         170824.0   85.125333   265.536667  174.632667
#            R    LR         170824.0   82.615200   164.660800  101.484800
#                 RR         170824.0   89.300952   196.146190  114.133810
#                 SR         170824.0  456.628824   268.998824  252.660588
#            S    LS         170824.0   94.524483   250.620345  205.966897
#                 RS         170824.0  109.202000   154.417333  190.259333
#                 SS         170824.0   42.150000   519.530000  397.240000

# %%
#Drop date since it is irrelevant
datagrouped = datagrouped.drop("Date", axis = 1)

# %%
datagrouped
# Out:
#                              HoldTime  LatencyTime  FlightTime
# UserKey    Hand Direction
# MAKSYM0000 L    LL          93.411200   175.358000  189.420800
#                 RL          84.521071   201.381429  124.586429
#                 SL          85.125333   265.536667  174.632667
#            R    LR          82.615200   164.660800  101.484800
#                 RR          89.300952   196.146190  114.133810
#                 SR         456.628824   268.998824  252.660588
#            S    LS          94.524483   250.620345  205.966897
#                 RS         109.202000   154.417333  190.259333
#                 SS          42.150000   519.530000  397.240000

# %% [markdown]
# ### I generate 27 features this way. I want each feature to be a column instead of a row. So I need to reprocess the dataframe a little bit

# %%
# Reset index to convert index levels back to columns
datagrouped = datagrouped.reset_index()

# Pivot the table to transpose it
pivoted = datagrouped.pivot_table(index="UserKey", columns=["Hand", "Direction"], values=["HoldTime", "LatencyTime", "FlightTime"])

# Flatten the multi-level column index
pivoted.columns = ['-'.join([hand, direction, metric]) for metric, hand, direction in pivoted.columns]

# Reset index to make 'UserKey' a column again
pivoted = pivoted.reset_index()

# Display the resulting DataFrame
print(pivoted)
# Out:
#       UserKey  L-LL-FlightTime  L-RL-FlightTime  L-SL-FlightTime  \
# 0  MAKSYM0000         189.4208       124.586429       174.632667
#
#    R-LR-FlightTime  R-RR-FlightTime  R-SR-FlightTime  S-LS-FlightTime  \
# 0         101.4848        114.13381       252.660588       205.966897
#
#    S-RS-FlightTime  S-SS-FlightTime  ...  S-SS-HoldTime  L-LL-LatencyTime  \
# 0       190.259333           397.24  ...          42.15           175.358
#
#    L-RL-LatencyTime  L-SL-LatencyTime  R-LR-LatencyTime  R-RR-LatencyTime  \
# 0        201.381429        265.536667          164.6608         196.14619
#
#    R-SR-LatencyTime  S-LS-LatencyTime  S-RS-LatencyTime  S-SS-LatencyTime
# 0        268.998824        250.620345        154.417333            519.53
#
# [1 rows x 28 columns]

# %%
#In form of function

def generate_new_features(data):
    datagrouped = data.groupby(["UserKey", "Hand" , "Direction"]).mean(["HoldTime","LatencyTime","FlightTime"])

    if "Date" in datagrouped.columns and not datagrouped["Date"].empty:
        datagrouped = datagrouped.drop("Date", axis = 1)

    
    # Reset index to convert index levels back to columns
    datagrouped = datagrouped.reset_index()
    
    # Pivot the table to transpose it
    pivoted = datagrouped.pivot_table(index="UserKey", columns=["Hand", "Direction"], values=["HoldTime", "LatencyTime", "FlightTime"])
    
    # Flatten the multi-level column index
    pivoted.columns = ['-'.join([hand, direction, metric]) for metric, hand, direction in pivoted.columns]
    
    # Reset index to make 'UserKey' a column again
    pivoted = pivoted.reset_index()

    return pivoted

generate_new_features(data)
# Out:
#       UserKey  L-LL-FlightTime  L-RL-FlightTime  L-SL-FlightTime  \
# 0  MAKSYM0000         189.4208       124.586429       174.632667
#
#    R-LR-FlightTime  R-RR-FlightTime  R-SR-FlightTime  S-LS-FlightTime  \
# 0         101.4848        114.13381       252.660588       205.966897
#
#    S-RS-FlightTime  S-SS-FlightTime  ...  S-SS-HoldTime  L-LL-LatencyTime  \
# 0       190.259333           397.24  ...          42.15           175.358
#
#    L-RL-LatencyTime  L-SL-LatencyTime  R-LR-LatencyTime  R-RR-LatencyTime  \
# 0        201.381429        265.536667          164.6608         196.14619
#
#    R-SR-LatencyTime  S-LS-LatencyTime  S-RS-LatencyTime  S-SS-LatencyTime
# 0        268.998824        250.620345        154.417333            519.53
#
# [1 rows x 28 columns]

# %%
data.shape[1]
# Out:
# 8

# %% [markdown]
# ### Join the patient information to the tappy information

# %%
# Function to read the file and get the value from the Nth row
def get_value_from_file(user_key, row_number):
    #file_path = f'physionetdotorg/files/tappy/1/extracted/Archivedusers/User_{user_key}.txt'
    file_path = f'physionetdotorg/files/maksymdata/User_{user_key}.txt'
    try:
        # Read the file
        with open(file_path, 'r') as file:
            lines = file.readlines()
            if len(lines) >= row_number + 1:  # Check if the file has enough lines
                # Split the line by space and get the second column (index 1)
                return lines[row_number].split(":")[1].strip("\n")
            else:
                return None  # Return None if the row_number is out of bounds
    except FileNotFoundError:
        return None  # Handle the case where the file does not exist

# Apply the function to each row to get the new column value
def join_all_info_apply(data):
    pivoted['BirthYear'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 0))
    pivoted['Gender'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 1))
    pivoted['Tremors'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 3))
    pivoted['DiagnosisYear'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 4))
    pivoted['Sided'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 5))
    pivoted['UPDRS'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 6))
    pivoted['Impact'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 7))
    pivoted['Levadopa'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 8))
    pivoted['DA'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 9))
    pivoted['MAOB'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 10))
    pivoted['Other'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 11))
    pivoted['Parkinsons'] = pivoted['UserKey'].apply(lambda x: get_value_from_file(x, 2))
    return pivoted

join_all_info_apply(pivoted)

# Display the resulting DataFrame
print(pivoted)
# Out:
#       UserKey  L-LL-FlightTime  L-RL-FlightTime  L-SL-FlightTime  \
# 0  MAKSYM0000         189.4208       124.586429       174.632667
#
#    R-LR-FlightTime  R-RR-FlightTime  R-SR-FlightTime  S-LS-FlightTime  \
# 0         101.4848        114.13381       252.660588       205.966897
#
#    S-RS-FlightTime  S-SS-FlightTime  ...  Tremors  DiagnosisYear  Sided  \
# 0       190.259333           397.24  ...    False         ------   None
#
#          UPDRS   Impact  Levadopa      DA    MAOB   Other  Parkinsons
# 0   Don't know   ------     False   False   False   False       False
#
# [1 rows x 40 columns]

# %% [markdown]
# # !!! ONLY FOR MAKSYM DATA !!!

# %%
# Save the resulting DataFrame to a CSV file
output_file_path = 'physionetdotorg/files/maksymdata/maksy_info.csv'
pivoted.to_csv(output_file_path, index=False)

# Display the resulting DataFrame
print(pivoted)
# Out:
#       UserKey  L-LL-FlightTime  L-RL-FlightTime  L-SL-FlightTime  \
# 0  MAKSYM0000         189.4208       124.586429       174.632667
#
#    R-LR-FlightTime  R-RR-FlightTime  R-SR-FlightTime  S-LS-FlightTime  \
# 0         101.4848        114.13381       252.660588       205.966897
#
#    S-RS-FlightTime  S-SS-FlightTime  ...  Tremors  DiagnosisYear  Sided  \
# 0       190.259333           397.24  ...    False         ------   None
#
#          UPDRS   Impact  Levadopa      DA    MAOB   Other  Parkinsons
# 0   Don't know   ------     False   False   False   False       False
#
# [1 rows x 40 columns]

# %%
print(pivoted["UserKey"])
# Out:
# 0    MAKSYM0000
# Name: UserKey, dtype: object

# %%
print(pivoted)
# Out:
#       UserKey  L-LL-FlightTime  L-RL-FlightTime  L-SL-FlightTime  \
# 0  MAKSYM0000         189.4208       124.586429       174.632667
#
#    R-LR-FlightTime  R-RR-FlightTime  R-SR-FlightTime  S-LS-FlightTime  \
# 0         101.4848        114.13381       252.660588       205.966897
#
#    S-RS-FlightTime  S-SS-FlightTime  ...  Tremors  DiagnosisYear  Sided  \
# 0       190.259333           397.24  ...    False         ------   None
#
#          UPDRS   Impact  Levadopa      DA    MAOB   Other  Parkinsons
# 0   Don't know   ------     False   False   False   False       False
#
# [1 rows x 40 columns]

# %%
pivoted["Gender"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 pivoted["Gender"]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Gender'

# %% [markdown]
# # Do it for all the files in directory
#
# The following piece of code is basically the amalgamation of everything that came before it but with loops applies so its done for ALL the files of directory and also writting the file to store the joined data

# %%
# Define the path to the directory containing the .txt files
directory_path = "physionetdotorg/files/tappy/1/extracted/TappyData/"
file_list = glob.glob(os.path.join(directory_path, "*.txt"))

# Define the maximum number of lines allowed
max_lines = 8_000_000

# Open the output file in append mode (CSV format)
with open("physionetdotorg/files/tappy/1/processed_10082024.csv", 'a') as output_file:
    header_written = False  # Flag to check if header is written

    for filepath in file_list:
        # Count the number of lines in the file
        with open(filepath, 'r') as file:
            line_count = sum(1 for line in file)
        
        # Check if the file exceeds the maximum allowed lines
        if line_count > max_lines:
            print(f"Skipping {filepath} as it exceeds {max_lines} lines.")
            continue  # Skip to the next file
    
        print(f"Working on: {filepath}")
        data1 = read_data(filepath)
        
        apply_remove_leading_zeros_from_float(data1)
        
        # Apply the validation function to each row
        data1['Valid'] = data1.apply(validate_row, axis=1)
        
        # Filter out invalid rows
        data1 = data1[data1['Valid'] == True]
        
        # Drop the 'Valid' column as it's no longer needed
        data1 = data1.drop(columns=['Valid'])
    
        if len(data1) > 0:
            data3 = variable_conversion_function(data1)
            pivoted = generate_new_features(data3)

            print(pivoted.shape[1])
            if pivoted.shape[1] == 28:
                
                pivoted = join_all_info_apply(pivoted)
        
                # Write to output CSV file
                if not header_written:
                    # Write the header once
                    pivoted.to_csv(output_file, index=False, header=True)
                    header_written = True
                else:
                    # Append data without the header
                    pivoted.to_csv(output_file, index=False, header=False)
                
                print(f"Processed data written to output file.")
# Out:
# Working on: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1612.txt
# Working on: physionetdotorg/files/tappy/1/extracted/TappyData/ZWBPPNQCUX_1608.txt
# 16
# Working on: physionetdotorg/files/tappy/1/extracted/TappyData/MG8XVA5BFA_1611.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 28
#      25 apply_remove_leading_zeros_from_float(data1)
#      27 # Apply the validation function to each row
# ---> 28 data1['Valid'] = data1.apply(validate_row, axis=1)
#      30 # Filter out invalid rows
#      31 data1 = data1[data1['Valid'] == True]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[12], line 17, in validate_row(row)
#      15 except ValueError:
#      16     return False
# ---> 17 if not (isinstance(row['Timestamp'], str) and pd.to_datetime(row['Timestamp'], format='%H:%M:%S.%f', errors='coerce') is not pd.NaT):
#      18     return False
#      19 if not (row['Hand'] in ['L', 'R', 'S']):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1101, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1099         result = convert_listlike(argc, format)
#    1100 else:
# -> 1101     result = convert_listlike(np.array([arg]), format)[0]
#    1102     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1103         result = bool(result)  # TODO: avoid this kludge.
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
#    5391 if isinstance(key, slice):
#    5392     # This case is separated from the conditional above to avoid
#    5393     # pessimization com.is_bool_indexer and ndim checks.
#    5394     return self._getitem_slice(key)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:381, in DatetimeLikeArrayMixin.__getitem__(self, key)
#     374 """
#     375 This getitem defers to the underlying array, which by-definition can
#     376 only handle list-likes, slices, and integer scalars
#     377 """
#     378 # Use cast as we know we will get back a DatetimeLikeArray or DTScalar,
#     379 # but skip evaluating the Union at runtime for performance
#     380 # (see https://github.com/pandas-dev/pandas/pull/44624)
# --> 381 result = cast("Union[Self, DTScalarOrNaT]", super().__getitem__(key))
#     382 if lib.is_scalar(result):
#     383     return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arrays/_mixins.py:286, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     284     result = self._ndarray[key]
#     285     if self.ndim == 1:
# --> 286         return self._box_func(result)
#     287     return self._from_backing_data(result)
#     289 # error: Incompatible types in assignment (expression has type "ExtensionArray",
#     290 # variable has type "Union[int, slice, ndarray]")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:548, in DatetimeArray._box_func(self, x)
#     545 def _box_func(self, x: np.datetime64) -> Timestamp | NaTType:
#     546     # GH#42228
#     547     value = x.view("i8")
# --> 548     ts = Timestamp._from_value_and_reso(value, reso=self._creso, tz=self.tz)
#     549     return ts
#
# KeyboardInterrupt:

# %% [markdown]
# # Comparing code exexution with VS without spark
#
# I will use a smaller subset of files so the run is not so intense. I will count the time and try to parallelize processes with spark.

# %% [markdown]
# ## No Spark

# %%
start_time = time.time()

# Define the path to the directory containing the .txt files
directory_path = "physionetdotorg/files/tappy/1/extracted/TappyData/"
file_list = glob.glob(os.path.join(directory_path, "*.txt"))

# Define the maximum number of lines allowed
max_lines = 80000

# Open the output file in append mode (CSV format)
with open("physionetdotorg/files/tappy/1/processed_test_no_spark.csv", 'a') as output_file:
    header_written = False  # Flag to check if header is written

    for filepath in file_list:
        # Count the number of lines in the file
        with open(filepath, 'r') as file:
            line_count = sum(1 for line in file)
        
        # Check if the file exceeds the maximum allowed lines
        if line_count > max_lines:
            continue  # Skip to the next file
    
        data1 = read_data(filepath)
        
        apply_remove_leading_zeros_from_float(data1)
        
        # Apply the validation function to each row
        data1['Valid'] = data1.apply(validate_row, axis=1)
        
        # Filter out invalid rows
        data1 = data1[data1['Valid'] == True]
        
        # Drop the 'Valid' column as it's no longer needed
        data1 = data1.drop(columns=['Valid'])
    
        if len(data1) > 0:
            data3 = variable_conversion_function(data1)
            pivoted = generate_new_features(data3)

            if pivoted.shape[1] == 28:
                
                pivoted = join_all_info_apply(pivoted)
        
                # Write to output CSV file
                if not header_written:
                    # Write the header once
                    pivoted.to_csv(output_file, index=False, header=True)
                    header_written = True
                else:
                    # Append data without the header
                    pivoted.to_csv(output_file, index=False, header=False)
                

print("With no Spark it took --- %s seconds ---" % (time.time() - start_time))
# Out:
# /tmp/ipykernel_1037/3090773486.py:4: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath, delimiter="\t", header = None)
# /tmp/ipykernel_1037/3090773486.py:4: DtypeWarning: Columns (4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath, delimiter="\t", header = None)
# /tmp/ipykernel_1037/3090773486.py:4: DtypeWarning: Columns (4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath, delimiter="\t", header = None)
# /tmp/ipykernel_1037/3090773486.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath, delimiter="\t", header = None)
# With no Spark it took --- 2783.942713022232 seconds ---

# %% [markdown]
# ## With Spark

# %%
start_time = time.time()

# Initialize a Spark session
spark = SparkSession.builder \
    .appName("TappyDataProcessing") \
    .getOrCreate()


# Define the path to the directory containing the .txt files
directory_path = "physionetdotorg/files/tappy/1/extracted/TappyData/"
file_list = glob.glob(os.path.join(directory_path, "*.txt"))

# Define the maximum number of lines allowed
max_lines = 80000

# Function to process each file
def process_file(filepath):
    print(f"Processing file: {filepath}")  # Log the file being processed
    
    # Count the number of lines in the file
    with open(filepath, 'r') as file:
        line_count = sum(1 for line in file)
    
    # Skip files exceeding the maximum allowed lines
    if line_count > max_lines:
        print(f"Skipping file {filepath} due to excess line count: {line_count}")
        return None
    
    # Read data from the file
    data1 = read_data(filepath)
    
    # Apply transformations and filtering
    apply_remove_leading_zeros_from_float(data1)
    data1['Valid'] = data1.apply(validate_row, axis=1)
    data1 = data1[data1['Valid'] == True].drop(columns=['Valid'])
    
    # If there's data after filtering, continue processing
    if len(data1) > 0:
        data3 = variable_conversion_function(data1)
        pivoted = generate_new_features(data3)
        
        # Ensure the DataFrame has the expected number of columns
        if len(pivoted.columns) == 28:
            pivoted = join_all_info_apply(pivoted)
            return pivoted
    
    return None

# Parallelize the file list and process files
rdd = spark.sparkContext.parallelize(file_list)

# Process each file and filter out None results
processed_data_rdd = rdd.map(process_file).filter(lambda x: x is not None)

# Collect the processed Pandas DataFrames
processed_data_list = processed_data_rdd.collect()

# Convert the list of Pandas DataFrames to a single Pandas DataFrame
if processed_data_list:
    print(f"Number of processed DataFrames: {len(processed_data_list)}")
    
    # Concatenate all the Pandas DataFrames
    combined_df = pd.concat(processed_data_list, ignore_index=True)
    
    # Define the output CSV file path
    output_csv_path = "physionetdotorg/files/tappy/1/processed_test_spark.csv"
    
    # Write the final DataFrame to a single CSV file
    if not os.path.exists(output_csv_path):
        # If the file doesn't exist, write with the header
        combined_df.to_csv(output_csv_path, index=False, mode='w', header=True)
    else:
        # If the file exists, append without the header
        combined_df.to_csv(output_csv_path, index=False, mode='a', header=False)

print("With Spark it took --- %s seconds ---" % (time.time() - start_time))

# Stop the Spark session
spark.stop()
# Out:
# 24/08/20 20:52:11 WARN Utils: Your hostname, MojoDojoCasaPC resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 24/08/20 20:52:11 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/08/20 20:52:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9ALACHPPUR_1702.txtProcessing file: physionetdotorg/files/tappy/1/extracted/TappyData/UUIZH9TDXR_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FXC5YFXZ0K_1610.txt
#
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UDCY90VKYN_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/STW9PUPHWN_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/R8CJDKFQJZ_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PRG54RZY7X_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SDZPQV3VZ1_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M0PBVLISCF_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZY9CCHSPF2_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/310NXPGJPD_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1612.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/R8CJDKFQJZ_1702.txt due to excess line count: 122636
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/Z1QLXS3DGS_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZI1KGKLCD5_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LVRTXTCS1Z_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AJHHNPKG0K_1611.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1701.txt due to excess line count: 145324
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZWBPPNQCUX_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MG8XVA5BFA_1611.txt
# /tmp/ipykernel_1037/3090773486.py:4: DtypeWarning: Columns (4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3MZWDTW7CC_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YQSGN9BMVK_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M4ARHBY168_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8TEUUGQBYB_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SDZPQV3VZ1_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NBISCUWYGS_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YACDBXUNSA_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZEA4RST93H_1609.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1701.txt due to excess line count: 97528
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JMIVIRFQRR_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UH6FQWXIZI_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/T0RR5A7EFV_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M0MTCXU0MH_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PRG54RZY7X_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PVADT62JUM_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/1XNJCXS3EY_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8EY6NZAKCI_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/81NEUZEBXI_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZY9CCHSPF2_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LIOUUNGQ8Q_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/S8Y5T8RWZ4_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDZHIUK2W2_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TAGYMXUFJE_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QEYMRM1ZSM_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZY9CCHSPF2_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9JRHCGCWAZ_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8EY6NZAKCI_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9JRHCGCWAZ_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GEYWAGTINR_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SW61HF6XRY_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PW8A521Y5K_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8TEUUGQBYB_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JHBOKKHOQW_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JHBOKKHOQW_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3MZWDTW7CC_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LFKWFNOFEM_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CAXCJIKLYM_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TBOPVHGLMX_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/7OIX84KINL_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QXLSWXKHEX_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDYIDJBAXF_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FHEOPKL3QQ_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GUDRVXO6RX_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SWJ4Q9V1NW_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FHEOPKL3QQ_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NKKUDKDMGQ_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GDGG19NBH7_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/O0L3RD63QP_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDYIDJBAXF_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EKG57AN0N6_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M0MTCXU0MH_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YAJFHG6OHD_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YAJFHG6OHD_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SPNOI40JCA_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GHRLW1IJRV_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PJRIZQJMKO_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UDCY90VKYN_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/7XS9VOLXWU_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GEYWAGTINR_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LKR3NUMIFS_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SDZPQV3VZ1_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/B4NL4SV9ZC_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/81NEUZEBXI_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UURLOSDUOA_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/HB2JCE24IE_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VVYPNRQ5KG_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFNOZ1KI1M_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RDJHNZGQL2_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZQ4UHHUPNZ_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WBS5I7VF1G_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZPXSHZSGKI_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FIWPKLWCT5_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/F8KU8UP2SZ_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/OMCPRWYBSQ_1610.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/OMCPRWYBSQ_1610.txt due to excess line count: 94971
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3MZWDTW7CC_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ITWTZ5F3VW_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6YXFEMHYZI_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFQWSP8ARK_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SDZPQV3VZ1_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/KE21ILBSOI_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WY25WHLA9D_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VZWQROMTLO_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PJU53Y7KVB_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SPNOI40JCA_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/Z2UPVHHGBE_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PWXIPGSKEF_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZIUU38ZJXA_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/81NEUZEBXI_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GEYWAGTINR_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1702.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1702.txt due to excess line count: 111136
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/G6OE5CXQPY_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/81NEUZEBXI_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1607.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1607.txt due to excess line count: 111601
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LSQWWDXEYO_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/95S93AXF86_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QEYMRM1ZSM_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LKYPMARSKU_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PRGWGP1WH4_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WBS5I7VF1G_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RWQHSVOUGI_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3HYXJCTCNT_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/KLM4CVXNRB_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9RCEHVGNCJ_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TDQGZRB2SU_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QPRYN1F9BZ_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZYWLN4JVLA_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZQ4UHHUPNZ_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SGT8K5GXG0_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/OTUYARXZX2_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1702.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1702.txt due to excess line count: 87276
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IZBOYJGXXB_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VIAXR21TSC_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UUIZH9TDXR_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LKR3NUMIFS_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GEYWAGTINR_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CAXCJIKLYM_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/0NMZ9JBBHI_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UMZFEO7IAG_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CPSM4LIXDS_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LSQWWDXEYO_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9IA0YLPHU2_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EX8J9DGRSY_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1610.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1610.txt due to excess line count: 135615
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JWGIQXYUDJ_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UUIZH9TDXR_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TBOPVHGLMX_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VVYPNRQ5KG_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/E7UA8EHENF_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/7XS9VOLXWU_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/U8RI3K0CGP_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1608.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1608.txt due to excess line count: 87579
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ITWTZ5F3VW_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9GBSZXI2BB_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IZBOYJGXXB_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFQWSP8ARK_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VVYPNRQ5KG_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EF9XEFXPBN_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QXLSWXKHEX_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFQWSP8ARK_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/927ZLCPEJM_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GEYWAGTINR_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ARUGT4UL2R_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UH6FQWXIZI_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1611.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1611.txt due to excess line count: 84660
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6LB9FQABZQ_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CAXCJIKLYM_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3MZWDTW7CC_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/C6UGS6P0J0_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JMIVIRFQRR_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/U25FAZCDZM_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MQJBGHOEXP_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9TUXDIR9EE_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/81NEUZEBXI_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/L9ULZGDITG_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GRPUBQLE4F_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JZVDCNBT1S_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PRGWGP1WH4_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PESPWEVTGF_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XPHHPHIVZ4_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M0MTCXU0MH_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QXLSWXKHEX_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YI43UM1CEH_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BFXNVL50DC_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/HYGNDIWHSC_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8EY6NZAKCI_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JWGIQXYUDJ_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QEYNMBJ8T0_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/J3QZ0MCD1Y_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SDZPQV3VZ1_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TBOPVHGLMX_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SEVJ2WXCKH_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6R9IGYWVWT_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LKYPMARSKU_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QEYMRM1ZSM_1611.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/QEYMRM1ZSM_1611.txt due to excess line count: 81635
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IZBOYJGXXB_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/O0L3RD63QP_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/48DZPAJ5NS_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/927ZLCPEJM_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/U25FAZCDZM_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FXC5YFXZ0K_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDYIDJBAXF_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RTBOZILJFT_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/J3QZ0MCD1Y_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SYUUDFV8IU_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZY9CCHSPF2_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5USOYSDCXB_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FFNMFHHSZJ_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9GBSZXI2BB_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NMMGWRY6SO_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5ARV4LHEJ0_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ACSKCOJC06_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/KTUVFFSLN4_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CAXCJIKLYM_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QEYMRM1ZSM_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BFXNVL50DC_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/7OIX84KINL_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/1HOEBIGASW_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5ARV4LHEJ0_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1701.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1701.txt due to excess line count: 88372
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/B4NL4SV9ZC_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ITWTZ5F3VW_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UJ2F1R6ODJ_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/R8CJDKFQJZ_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/G6OE5CXQPY_1701.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/G6OE5CXQPY_1701.txt due to excess line count: 414786
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AJHHNPKG0K_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFQWSP8ARK_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YQSGN9BMVK_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/81NEUZEBXI_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GEYWAGTINR_1612.txt
# /tmp/ipykernel_1037/3090773486.py:4: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VIAXR21TSC_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/S5FSMHZEYI_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/55KMBQR3HH_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SGT8K5GXG0_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/927ZLCPEJM_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/V2SZVYXBOD_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/L7Q16SJ7KP_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/4XPHKKBXS6_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GN3N4ZNCV9_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BBCWCBNBPR_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IZBOYJGXXB_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/927ZLCPEJM_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/7QVQD5IJEH_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9ZRBC5WOZR_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZWBPPNQCUX_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/OMCPRWYBSQ_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/927ZLCPEJM_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/S9C3TTX3NE_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/0QAZFRHQHW_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JHBOKKHOQW_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YNESMGNGWK_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SH6ZX4UKRO_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UH6FQWXIZI_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NBISCUWYGS_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ERFIZ5O8FM_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M4ARHBY168_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1612.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1612.txt due to excess line count: 86008
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EZF9NAHLOU_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/310NXPGJPD_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BIGWMXFU3B_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UFMGBC58XD_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZEA4RST93H_1608.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/ZEA4RST93H_1608.txt due to excess line count: 106388
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FIWPKLWCT5_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SH6ZX4UKRO_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/R3OKI24Z0Q_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CAXCJIKLYM_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MDL9KS0SFL_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GOCJ4TNPII_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/X7PEJ5EG77_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YI43UM1CEH_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFNOZ1KI1M_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1611.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1611.txt due to excess line count: 163523
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YWMIQIQND3_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1608.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1608.txt due to excess line count: 150591
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/H08AW2YBAJ_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IZBOYJGXXB_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FX9KOOZRZL_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QEYMRM1ZSM_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZQ4UHHUPNZ_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FHEOPKL3QQ_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3DIXPRIOSW_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/I3U47MF5UF_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PHOPRDDRXM_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/O0L3RD63QP_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/4IE6CIRI0V_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/0EA27ICBLF_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/F56FSV2EP7_1702.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/0EA27ICBLF_1607.txt due to excess line count: 142635
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VCTVD6LMPK_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/HB2JCE24IE_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QCFNDCZPQH_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GRPUBQLE4F_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/927ZLCPEJM_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/V2SZVYXBOD_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WBS5I7VF1G_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZEA4RST93H_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFQWSP8ARK_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZCPALNB4ZM_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JZVDCNBT1S_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/4GUYFBZMK9_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FIWPKLWCT5_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8TEUUGQBYB_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8EY6NZAKCI_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LKR3NUMIFS_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QCFNDCZPQH_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CPSM4LIXDS_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/E0XRQVF05S_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YI43UM1CEH_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M4ARHBY168_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1701.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1701.txt due to excess line count: 98340
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GMCJGJHMZN_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VVYPNRQ5KG_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MFAQFDW3IH_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CAXCJIKLYM_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1610.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1610.txt due to excess line count: 82046
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZQ4UHHUPNZ_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CYC6IZJYTE_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZWHGXDUDLG_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NMMGWRY6SO_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZY9CCHSPF2_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WXNQ0QM0XD_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/E0TBSMYHQI_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EF9XEFXPBN_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TAGYMXUFJE_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/R3OKI24Z0Q_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZQ4UHHUPNZ_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UDCY90VKYN_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GRPUBQLE4F_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IZBOYJGXXB_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9GBSZXI2BB_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5YFAPLRCMD_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3DIXPRIOSW_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LEFLOMUTBN_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1609.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1609.txt due to excess line count: 141815
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BFXNVL50DC_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/B4NL4SV9ZC_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFNOZ1KI1M_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/2X17VCRRQA_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LSQWWDXEYO_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/1BMKGIOSHF_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/0QAZFRHQHW_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AJHHNPKG0K_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZGZJSOXBWP_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LSQWWDXEYO_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XQIXWF0BXG_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FIWPKLWCT5_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/F8KU8UP2SZ_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/KRJVEQSLL5_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TQCMYNHOSM_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JMYZ5IKGWE_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FHEOPKL3QQ_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AJIGSB2YPW_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EBGLZDVO5S_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZQ4UHHUPNZ_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SDZPQV3VZ1_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GHRLW1IJRV_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YI43UM1CEH_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RYQGAPGNAM_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YNESMGNGWK_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/E0TBSMYHQI_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UYBDVXACTH_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8EY6NZAKCI_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/K2VMDST8HC_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AVNGRDUXE5_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FHEOPKL3QQ_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZCPALNB4ZM_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UJ2F1R6ODJ_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZFADOEIUOD_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZEA4RST93H_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BIGWMXFU3B_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XPHHPHIVZ4_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/E0TBSMYHQI_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YYPKGX6B24_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFQWSP8ARK_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZQ4UHHUPNZ_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/C6UGS6P0J0_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SYUUDFV8IU_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RWPUNZZ3EF_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/R3OKI24Z0Q_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WBS5I7VF1G_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JIRZDKEJQN_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZI1KGKLCD5_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RDJHNZGQL2_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MQ6HDDONF0_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/39KQRZCESF_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LIOUUNGQ8Q_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EMYGMAIB2L_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FIWPKLWCT5_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDYIDJBAXF_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JDWYGP605O_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AJHHNPKG0K_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SKLXBAOSN4_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BBCWCBNBPR_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IZBOYJGXXB_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LFKWFNOFEM_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VSBEPFSFWK_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WHTIJRQSYC_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6LB9FQABZQ_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5PQVTWULAC_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/K2VMDST8HC_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BZ8MQ2TBMS_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/9RCEHVGNCJ_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/39KQRZCESF_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ASP8RSNO73_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LSQWWDXEYO_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XZ9HNUO4KO_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PWXIPGSKEF_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RWQHSVOUGI_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/E0TBSMYHQI_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/2JTCBKUP8T_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EX8J9DGRSY_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8EY6NZAKCI_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YIA9DW5AGQ_1608.txt
# /tmp/ipykernel_1037/3090773486.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5ARV4LHEJ0_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VVYPNRQ5KG_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GRPUBQLE4F_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZQ4UHHUPNZ_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NMMGWRY6SO_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/KEWWVGP2NM_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QPEDAXESTL_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ICXFP2WKAU_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CAXCJIKLYM_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QXLSWXKHEX_1611.txt
# /tmp/ipykernel_1037/3090773486.py:4: DtypeWarning: Columns (4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GRPUBQLE4F_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JMYZ5IKGWE_1701.txtProcessing file: physionetdotorg/files/tappy/1/extracted/TappyData/LIOUUNGQ8Q_1701.txt
#
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VR0LFE1JUC_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDYIDJBAXF_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MNMBCKNAAS_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8EY6NZAKCI_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/HVSWQYNG2N_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EKG57AN0N6_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CEU6KM05RU_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M4ARHBY168_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VCFUOTMSKT_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/L7Q0BDRZ9C_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDZHIUK2W2_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TLR6R7C7AP_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/A0K1FZANZN_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZY9CCHSPF2_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WY25WHLA9D_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AVNGRDUXE5_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LIPRETG9WY_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/81NEUZEBXI_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QCFNDCZPQH_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDYIDJBAXF_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JHBOKKHOQW_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CYC6IZJYTE_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WBS5I7VF1G_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UBO5EZ7IIH_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/S0YGDLIF9V_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M6MUS5WY6N_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/C6UGS6P0J0_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GN3N4ZNCV9_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/F56FSV2EP7_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LKR3NUMIFS_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QDV7XQWLI7_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/2JTCBKUP8T_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/0NMZ9JBBHI_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFQWSP8ARK_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/COK8G1W7JY_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WDNE1Q9EHT_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NCHCW5MTBJ_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FIWPKLWCT5_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/HQGUVYLVZH_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JMIVIRFQRR_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/OMCPRWYBSQ_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/48DZPAJ5NS_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SKLXBAOSN4_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LSQWWDXEYO_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NSYGJALQVO_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/OAXZCZWN7W_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8MERXVINPN_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZIUU38ZJXA_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TLR6R7C7AP_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/95S93AXF86_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MDL9KS0SFL_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/BENXJNDSC4_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PRGWGP1WH4_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YNVRRFC8S4_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GHRLW1IJRV_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SOP2REQFUH_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CYC6IZJYTE_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RYQGAPGNAM_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/F8KU8UP2SZ_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EF9XEFXPBN_1607.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1611.txt due to excess line count: 273274
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDZHIUK2W2_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/Q6MXNH0MGM_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/P8HEQZSYJN_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/7HTEQAAWWO_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDYIDJBAXF_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6VH7AFDQ32_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/R8CJDKFQJZ_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/KKTY9PC9XM_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M4ARHBY168_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZY9CCHSPF2_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/CAXCJIKLYM_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/Z2UPVHHGBE_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/G6OE5CXQPY_1702.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/G6OE5CXQPY_1702.txt due to excess line count: 243839
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/SEVJ2WXCKH_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/927ZLCPEJM_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VSBEPFSFWK_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VVYPNRQ5KG_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WBS5I7VF1G_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5PQVTWULAC_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/E1E2I8HUGC_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AFQWSP8ARK_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/M0MTCXU0MH_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EF9XEFXPBN_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AEKGFUEQUU_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MG8XVA5BFA_1609.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/MG8XVA5BFA_1609.txt due to excess line count: 106148
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JMIVIRFQRR_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ERFIZ5O8FM_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YNVRRFC8S4_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GN1CUIPUTJ_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/IDYIDJBAXF_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PVADT62JUM_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TBOPVHGLMX_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FFNMFHHSZJ_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UYBDVXACTH_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MDL9KS0SFL_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZT9ASWFCFS_1606.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NMKZDOICAB_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LA6KW35OXK_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LVRTXTCS1Z_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FFNMFHHSZJ_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1702.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/NPACI6EW26_1702.txt due to excess line count: 80552
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LKR3NUMIFS_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GRPUBQLE4F_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AEKGFUEQUU_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UUIZH9TDXR_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MG8XVA5BFA_1610.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/MG8XVA5BFA_1610.txt due to excess line count: 98412
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QEYNMBJ8T0_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EAGGQIYQYT_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3MZWDTW7CC_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TBOPVHGLMX_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TAGYMXUFJE_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UDCY90VKYN_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/0NMZ9JBBHI_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QXLSWXKHEX_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/QAH9IVALVC_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/95S93AXF86_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8EY6NZAKCI_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GRPUBQLE4F_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EF9XEFXPBN_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WHUETYQCMK_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FHEOPKL3QQ_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/GEYWAGTINR_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/927ZLCPEJM_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WBS5I7VF1G_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PRGWGP1WH4_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PRGWGP1WH4_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EF9XEFXPBN_1610.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WBS5I7VF1G_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/KRJVEQSLL5_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/LVRTXTCS1Z_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FIWPKLWCT5_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/FHEOPKL3QQ_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WXNQ0QM0XD_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/MG8XVA5BFA_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8TEUUGQBYB_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/XWAX2IHF3O_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8O9IAIA9L1_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/PRGWGP1WH4_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5ARV4LHEJ0_1611.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/TL2XHTLK1T_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/HSOCXZDCZM_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8MERXVINPN_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WCNUFGGLYB_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/EF9XEFXPBN_1612.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/0EA27ICBLF_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/8TEUUGQBYB_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/3MZWDTW7CC_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/WCNUFGGLYB_1702.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/ZI1KGKLCD5_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/YCQJAEI7RN_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/RDJPGMWKAG_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/UJ2F1R6ODJ_1701.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/JQ0YSY0AYO_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/HAEZ2A3NM5_1607.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/L2GM3QU5IO_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/5YFAPLRCMD_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/VDKQJZARYF_1609.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/S0YGDLIF9V_1703.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/AXXXXBBCCH_1608.txt
# Processing file: physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1609.txt
# Skipping file physionetdotorg/files/tappy/1/extracted/TappyData/6WBXSDG5BB_1609.txt due to excess line count: 94355
# Number of processed DataFrames: 394
# With Spark it took --- 152.65561532974243 seconds ---

# %% [markdown]
# With no Spark it took --- 2783.942713022232 seconds ---
#
# With Spark it took --- 152.65561532974243 seconds ---
